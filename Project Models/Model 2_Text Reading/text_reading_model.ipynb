# %%
# !pip install opencv-python pytesseract pyttsx3
# Out:
# Requirement already satisfied: opencv-python in c:\users\smart\appdata\roaming\python\python311\site-packages (4.8.0.76)
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pytesseract in c:\users\smart\appdata\roaming\python\python311\site-packages (0.3.10)
# Requirement already satisfied: pyttsx3 in c:\users\smart\appdata\roaming\python\python311\site-packages (2.90)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\smart\appdata\roaming\python\python311\site-packages (from opencv-python) (1.26.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\smart\appdata\roaming\python\python311\site-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\smart\anaconda3\lib\site-packages (from pytesseract) (10.3.0)
# Requirement already satisfied: comtypes in c:\users\smart\appdata\roaming\python\python311\site-packages (from pyttsx3) (1.2.0)
# Requirement already satisfied: pypiwin32 in c:\users\smart\appdata\roaming\python\python311\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\smart\appdata\roaming\python\python311\site-packages (from pyttsx3) (306)

# %%
import cv2
import pytesseract
import pyttsx3

# %%
# Set up Tesseract executable path
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
# Initialize text-to-speech engine
engine = pyttsx3.init()

# %%
# Start capturing video from the camera
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Apply OCR to the grayscale image
    text = pytesseract.image_to_string(gray)

    # Print the extracted text
    print(text)

    # Use text-to-speech to read the text
    engine.say(text)
    engine.runAndWait()

    # Display the frame
    cv2.imshow('Camera', frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close any OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ‘S
#
# sap Leerning for Futter -The
# (Complete Fumer ML Guide | Udemy
#
# Te Gee 6 Prager Remctis Fa, howd se
# ee ges eae,
#
# ms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tl sd asell
# edd
# pl! wilp slaaill Dyai
# Lal big!
#
# Aae> 4 pial
#
# TT iesh bute © oeddl eSieu
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lello sa
# — ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lem
# O112H eo |
